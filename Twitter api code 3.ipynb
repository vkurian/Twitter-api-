# %%
import sys
import operator
import requests
import json
import twitter
import datetime

# %%
import tweepy
import time
import requests
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sqlalchemy import create_engine 
my_conn=create_engine("mysql+pymysql://root:""@localhost:3306/test")

# %%
consumer_key = 'EpGEps3HQU0Em9GRQ611680cl'
consumer_secret = 'oBA8gFEqbPhoPHuGWWhkg15IyW5TUjlk3X7a1Kbx39BhBr7lBb'
access_token = '1493363962716508163-qir2LakyYEv8Fxubdhbvj9Q1ORDoVq'
access_secret = 'WjjQEo0f78rSLXDVDdLDjRPGuvD9VnbbRFMxMay3YuBXH'
bearer_token = 'AAAAAAAAAAAAAAAAAAAAABuJZQEAAAAAhcrrEQmNAMxGipN773v2X0b939g%3DZ4R2y26ikjPeFVDmcX6eN73R36xqHJlOvvmKPvrGYd4xQ8zTI3'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
#we can change number of tweets to whatever you need
num_tweets = 100
tweets = []
likes = []
time = []
retweets = []

# this allows us to set the time to the exact time the code is being ran, and itll automatically go back 7 days for us without inputting the new date everytime
today = datetime.datetime.now()
today = today.replace(hour=23, minute=59, second=59, microsecond=999999) # set from the beggining of the day
time_to_the_past = 7 # 7 because we want a week before today
week = today - datetime.timedelta(time_to_the_past) 
next_day = week + datetime.timedelta(time_to_the_past)

# %%
# the "until = 'date' will make it so we can gather tweets from that date till now ; WE CAN ONLY GO BACK 7 DAYS
for t in tweepy.Cursor (api.search_tweets,
                        q= "Mcdonalds -filter:retweets",
                        result_type = ['popular'],
                        lang = 'en',
                        until = next_day.date(),
                        tweet_mode='extended').items(num_tweets):
    tweets.append(t.full_text)
    likes.append(t.favorite_count)
    time.append(t.created_at)
    retweets.append(t.retweet_count)
    #vs = analyzer.polarity_scores(tweets)
    #scores.append(vs)
    #print("{:-<65} {}".format(tweet, str(vs)))

# %%
df = pd.DataFrame({'tweets':tweets, 'likes':likes,'retweets':retweets, 'time':time})

df.sort_values("likes",ascending=False)


from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
scores = []
for tweet in tweets:
    vs = analyzer.polarity_scores(tweet)
    scores.append(vs)
    print("{:-<65} {}".format(tweet, str(vs)))
# Out:
# Former McDonald's CEO sets up group to fight back against woke corporations | Daily Mail Online https://t.co/m4IkIl2HZY {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compound': -0.3818}
# @YungMiami305 Mcdonalds burgers are made with human remains------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @emilyscinto @McDonalds My life got considerably worse when I couldn't get an egg McMuffin for dinner {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.5256}
# @JCinCleveland @McDonalds And……..haha. Bring it on.-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @FlippMint sasha waybright as the mcdonalds logo :D-------------- {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'compound': 0.6166}
# i woulda had mcdonalds no doubt https://t.co/6DqAcYqx8r---------- {'neg': 0.0, 'neu': 0.74, 'pos': 0.26, 'compound': 0.2755}
# @LINNFUCIUS Or McDonalds pays $15/hr, so in 6hrs someone can make $90 and probably have more fun. {'neg': 0.0, 'neu': 0.817, 'pos': 0.183, 'compound': 0.5563}
# @NM_UAP For sure, its not cut and dried. What does Putin hope to rule, besides ashes ?
# If you think of how the younger generation in Russia must feel. No internet, no netflix, no spitify, no mcdonalds. You can be sure there is a deep rooted hatred brewing within Russia itself. #implosion {'neg': 0.099, 'neu': 0.668, 'pos': 0.233, 'compound': 0.6786}
# @McDonalds you can do better than this--------------------------- {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}
# my son just screamed “give me my drink” through the window at the drive thru cvs pharmacy tech. bro this is not mcdonalds {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'compound': -0.3182}
# @McDonalds what y'all waiting on??? https://t.co/AQi9sYHXK1------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @IntonerHen now I want a chibi show about McDonalds Kaine-------- {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.0772}
# mcdonalds question mark------------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# drunk n high rn waiting in the car for her to bring me mcdonalds- {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'compound': -0.34}
# @McDonalds make vegetarian nuggets or begin the road to eventual bankruptcy like it’s ur choice {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.3612}
# waffle fries from mcdonalds r mid just buy normal fries---------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Former #McDonalds 's CEO who invented the McNugget sets up new group to fight back against woke corporations and buys enough #BankofAmerica shares to formally propose that firm scraps staff CRT training https://t.co/5Ls8yFOG8L {'neg': 0.073, 'neu': 0.866, 'pos': 0.061, 'compound': -0.1027}
# @VeraBambiLIVE @McDonalds You have no idea how hard it is for me right now to not unfollow you just for the sake of the joke {'neg': 0.129, 'neu': 0.791, 'pos': 0.079, 'compound': -0.1027}
# Before making six figures from my 9-5, I worked:
#
# Fast food - McDonalds 🍔
# Retail - Best Buy + Old Navy 🛍
# Admin - college + state dept. 🗄
# Security - mall + Gap 👮🏾‍♀️
# Delivery - FedEx + catering 🚚
# Military - Marines 🥷🏾
#
# By 30 making $23k b4 taxes. I’m familiar w/#thestruggle. {'neg': 0.0, 'neu': 0.907, 'pos': 0.093, 'compound': 0.765}
# @McDonalds your customer support is 🚮---------------------------- {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
# McDonalds gets to much hate-------------------------------------- {'neg': 0.481, 'neu': 0.519, 'pos': 0.0, 'compound': -0.5719}
# I mean, can the steady diet of McDonalds, KFC, Diet Coke and adderall just… do it’s job already? I’m so fucking sick of his wretched face. 🙄 https://t.co/X7mAyKb47y {'neg': 0.114, 'neu': 0.886, 'pos': 0.0, 'compound': -0.5956}
# @anahibazan12 Mcdonalds frappe----------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @tacobell and @McDonalds y’all can stop pretending your lobby’s are closed for the safety of the community now {'neg': 0.103, 'neu': 0.701, 'pos': 0.196, 'compound': 0.25}
# There is no such thing as fast food anymore.
# Placed my McDonalds order on their in store screen at 7:27.
# 7:54 and still no food. {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.5267}
# @barstoolsports @martymush McDonalds large Coke
# Del Taco Cheesecake Bites
# 5 Guy Double bacon burger
# In-N-Out Double double
# Arby’s Curly Fries
#
# Am I proud of this list? No! But it’s the RIGHT LIST {'neg': 0.0, 'neu': 0.93, 'pos': 0.07, 'compound': 0.3274}
# @barstoolsports @martymush McDonalds Coke, KFC popcorn chicken, Original spicy chicken from Wendy’s, Potbelly Oreo shake, curly fries from Arby’s. {'neg': 0.081, 'neu': 0.81, 'pos': 0.11, 'compound': 0.1531}
# @McDonalds  come on McDonald's this is what you get for a large fry these days https://t.co/pItZq0qTCF {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# *banned McDonalds*----------------------------------------------- {'neg': 0.75, 'neu': 0.25, 'pos': 0.0, 'compound': -0.4588}
# not even kidding, i had soda 2 hours ago 😀 my friend bought mcdonalds and i caved 😀 {'neg': 0.051, 'neu': 0.628, 'pos': 0.322, 'compound': 0.7848}
# @jaxinn More like McDonalds for another Big Mac.----------------- {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.4201}
# @craig_soderdahl Is McDonalds not the same? 1st a marketing co, 2nd a RE company, 3rd a burger joint? {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @FoxNews @GOP @GOPChairwoman is pictured here having just received the news that Donald Trump is going to feed her a @McDonalds cheeseburger as part of a new reality prank series premiering this Sunday on @MTV. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Somehow I don’t believe this is what McDonald’s meant for their Happy Meal apple slices. @McDonalds https://t.co/BJKqyZcZPe {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'compound': 0.5719}
# Former McDonald’s CEO sets up group to fight back against woke corporations https://t.co/rTmJ2mQIMc {'neg': 0.178, 'neu': 0.822, 'pos': 0.0, 'compound': -0.3818}
# Former McDonald's CEO sets up group to fight  woke corporations https://t.co/P2DxgLJzAo @MailOnline {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'compound': -0.3818}
# Former McDonald’s CEO sets up group to fight back against woke corporations https://t.co/TZRJ1OysqA {'neg': 0.178, 'neu': 0.822, 'pos': 0.0, 'compound': -0.3818}
# McDonalds Blue Powerade, Oreo and M&amp;M McFlurry, Crunch Wrap Supreme Tbell, 3x3 animal style In-n-Out, Checkers fries https://t.co/8ZAkqmxXgC {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.5574}
# @IamRichWilson Are we clear this is a Greg's thing or do you mean gnerally/ Ginsters (usually the main diet of a stand up)? Is it like McDonalds?- dirty but you need it? {'neg': 0.056, 'neu': 0.828, 'pos': 0.117, 'compound': 0.2824}
# What incentive does this give the commission to vote for a different map that meets constitutional muster?
#
# None.
#
# This is like telling your child..
#
# If you don’t pick a healthy dinner option by 5:59…Then we will be forced to get McDonalds at 6.
#
# #fairmaps https://t.co/NmVT4kmlGU {'neg': 0.1, 'neu': 0.799, 'pos': 0.101, 'compound': 0.0232}
# I done seen that Rif McDonalds application tweet about 16 times today {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @barstoolsports @martymush A&amp;W root beer float, McDonalds apple pie, KFC Chicken sandwich, Five Guys bacon double cheeseburger, Arby’s curly fries. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @codinghorror McDonalds is like all franchises. Some are great, some are shit. {'neg': 0.188, 'neu': 0.469, 'pos': 0.344, 'compound': 0.4588}
# @_penname @McDonalds @Wendys OOOOOOHHHHHH!  I just walked in my house but that is the best idea!  Snack tomorrow :) {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.9078}
# @Tintamarre6 McDonalds after $15 an hour minimum wage is passed nationally. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @DelusionsMass @BL20422822 @AlexVickeryHowe @6lennybravo @Jaisans @MinnesotaExpat @RAM0667 @Alfred_StatesX @aSinister @glinch72 @MedBennett @CorpulentWidow @DebraMMason1 @JonRFleming @theDVSMarcus @WalrusesAreCool @JohnOz1900 @girl_pilled @ALefty123 @cbeckj @Barbarajdurkin @insane_voice @NavyBrat59 @ItsTheAtmospher @Anvndarnamn5 @DeniersAreDerp @fishyfish67 @ShastaGecko @EducatingTrump2 @Neilcharles1450 @GSwarthout @JeffBernard1 @Based_inReality @RobertVonB1 @RustyAway @ChrisBBacon3 @BellRoniBell @Jonnyporkchop @DamienHamilto17 @biffmack @Racing_Mackay @jpgcrowley @GaryWHall @Lorrilala @andyboulo @ponycar06 @canalzone68 @KevinSecular2 @SeanFlan45 @Narvuntien Imagine the smell after playing golf in the hot and humid Florida sun...drinking all those diet Cokes, pounding those McDonalds, filling those diapers. Yikes. {'neg': 0.0, 'neu': 0.976, 'pos': 0.024, 'compound': 0.2023}
# That concludes today's class in cash (which we don't validate on earth would give free during the dust of the bars in Mcdonalds! {'neg': 0.079, 'neu': 0.786, 'pos': 0.135, 'compound': 0.3574}
# @MmichaelLlucy @tfswebb I'm sure it derives from the Junior Burger menu item that was sold at McDonalds in Australia until the early 2000s (?). Bit hard to find with a cursory Google when it became just the "hamburger" which I'm pretty sure is how it was always sold in the US: https://t.co/1LHEi5gORW {'neg': 0.024, 'neu': 0.839, 'pos': 0.136, 'compound': 0.7506}
# @KimShiJin8 @youknowstobit Like Tae in that McDonalds scene was so cute!!! {'neg': 0.0, 'neu': 0.554, 'pos': 0.446, 'compound': 0.8043}
# McDonalds is full of middle schoolers 😂-------------------------- {'neg': 0.129, 'neu': 0.612, 'pos': 0.259, 'compound': 0.4404}
# @Andreas43937443 @MysterySolvent Two Ass Nozzles filling their fake tanned nutsacks (suspiciously orange colored, dripping with flop sweat) with McDonalds "Orange Drink." {'neg': 0.408, 'neu': 0.592, 'pos': 0.0, 'compound': -0.8934}
# @McDonalds Bring back the cinnamon danish you used to sell.------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @deannam_409 @McDonalds @Wendys Mcds fries, Wendy's frosty------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @team_Dji @McDonalds Wow!!! I’m going to repost mine!!----------- {'neg': 0.0, 'neu': 0.585, 'pos': 0.415, 'compound': 0.7156}
# @ovrhtd AAL YOU DRINK WATER FROM MCDONALDS!/!.!.‘man------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @ClTYOFMON we were associating the noises in the bg with the mcdonalds collab 😭 {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'compound': -0.4767}
# @prankstercleric If you're gonna keep saying it, I might end up believing you're /just/ saying it.
#
# Might. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @barstoolsports @martymush McDonalds Sprite, Capn Crunch Delights from Taco Bell, 12 pc Nuggets from ChicFilA, Five Guys Burger, ChicFilA Fries 😋 {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.4588}
# @Goatisse 👀👀 McDonalds??----------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @tfswebb I assume it comes from McDonalds. It was/is their smallest burger. It had the least number of ingredients/fillings. {'neg': 0.064, 'neu': 0.936, 'pos': 0.0, 'compound': -0.0572}
# @emilyscinto Oh my goodness! @McDonalds responded! You’ve made it! {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.5962}
# @LokelaniRocks Don't go to McDonalds!!!🤦‍♂️😂😂😂😂------------------ {'neg': 0.17, 'neu': 0.47, 'pos': 0.36, 'compound': 0.9095}
# mcdonalds made me really bad coffee so in conclusion i will never be happy ever again🧍‍♂️🧍‍♂️ {'neg': 0.274, 'neu': 0.726, 'pos': 0.0, 'compound': -0.7777}
# OKAY
# freddies
# panera
# whataburger
# chickfila (i have it everyday though)
# mcdonalds (i had it yesterday)
# KFC (I FORGOT ABOUT KFC OMG)
# popeyes
# WHICH ONE???? {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.5563}
# @RisenPhoenix01 @Bladee90210 @atlstro2 Yeat is the goat. In all of my 45 years of life, I have never discovered an artist as great as Yeat. Before discovering Yeat's gracious discography, I was broke. I worked at McDonalds. I’ve changed. Yeat gave me a reason to exist. I love Yeat. {'neg': 0.047, 'neu': 0.754, 'pos': 0.199, 'compound': 0.8779}
# @LeniCrook @McDonalds They answered me…still terrible though----- {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.4767}
# The @McDonalds at gallery place is NOT it!!!!! Sodas flat and juice watery af 🤮🤮🤮 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Check out MCDONALDS HAPPY MEAL TOYS LOT Hercules/Aladdin/Chronicles of Narnia  https://t.co/HZtCZfBRNa #eBay via @eBay
# #McDonalds #toys #nostalgia #HappyMeal {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.6633}
# @Bladee90210 @atlstro2 Lil pump is the goat. In all of my 45 years of life, I have never discovered an artist as great as Lil pump. Before discovering Lil pump’s gracious discography, I was broke. I worked at McDonalds. I’ve changed. Lil pump gave me a reason to exist. I love Lil pump. {'neg': 0.044, 'neu': 0.769, 'pos': 0.187, 'compound': 0.8779}
# unsan food // i hope shidou eats mcdonalds on his trip to kentucky so he has to shit for like 12 hours until he gets home {'neg': 0.113, 'neu': 0.719, 'pos': 0.169, 'compound': 0.2023}
# @VeraBambiLIVE @McDonalds Well then. It's been fun Vera. A shame our friendship ended over donuts. https://t.co/uuFZHK8Mg9 {'neg': 0.132, 'neu': 0.513, 'pos': 0.355, 'compound': 0.6369}
# @jaxinn More likely McDonalds.----------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Gonna get super stoned and finished all the saw movies but first… mcdonalds 🧑‍🏭 {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.3506}
# Absolutely nobody at all:
#
# @McDonalds at the house: https://t.co/S3K1tcvZUp {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @Getclipped1738 @MUVARELL Mcdonalds------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @MaceoJernigan There’s a 100% chance you work at McDonalds with your level of intelligence 🥴 {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'compound': 0.6249}
# Lockdown messed with this Mcdonalds------------------------------ {'neg': 0.375, 'neu': 0.625, 'pos': 0.0, 'compound': -0.34}
# Paddington is the Burger King to Winnie the Pooh’s McDonalds as far as the “a boy and a bear” subgenre goes The Revenant also falls into this category, and they are Denny’s. No I will not elaborate. {'neg': 0.058, 'neu': 0.942, 'pos': 0.0, 'compound': -0.296}
# Freestlye Machine Vanilla Coke Wendys Chocolate Frostie Popeyes Chicken Sandwich Cheesey Gordita Crunch Mcdonalds fries https://t.co/hc2WcOhreR {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @_mirandawrites we would be happy to help, Miranda. let's talk more in detail about your order and the location via the link: https://t.co/WhvwT8dw7y {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.7506}
# @POTUS @Bill_Maxwell_ I noticed a local McDonalds is staying open till 2am (not that I’ll go there at that hour). That must mean they have enough employees to staff that.  And the pay is much better than 2 years ago. {'neg': 0.033, 'neu': 0.898, 'pos': 0.069, 'compound': 0.3612}
# @laurenboebert Just to give a few examples of stuff conversatives have tried protesting against:
#
# Nike
# McDonalds
# Coca Cola
# Pepsi
# Gillette
# Kelloggs
# Amazon
# Target
# NASCAR
# Kuerig
# Wal Mart
# UPS
# MLB
# Delta Airlines
# Cisco
# Quaker
# Citibank
#
# Are these all broke? {'neg': 0.132, 'neu': 0.827, 'pos': 0.04, 'compound': -0.5994}
# Thank you for feeding me @McDonalds for the last 3 days. Using the McDonald's app to get my free fries, I order a McChicken and a large sweet tea.. $2.86 {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'compound': 0.8316}
# Get Kyrie a McDonalds Sprite and he’ll go for 40----------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# McDonalds Big Mac prices compared to Japanese price (local price converted to JPY)
# Japan = 390 JPY = 100%
# Singapore = 539 JPY = 139%
# UK = 585 JPY = 150%
# New Zealand = 694 JPY = 178%
# USA = 773 JPY = 198% !
#
# A Big Mac in US costs double what it costs in Japan {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @brikiorr Receiving McDonalds cold should be illegal cos then you really clock that it’s not real food. {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.5574}
# I can't stay silent any longer. Fast food fries have gone to hell in a handbasket. Only McDonalds continues to bring an edible fry. The rest are a mess. this has to be fixed {'neg': 0.182, 'neu': 0.818, 'pos': 0.0, 'compound': -0.7964}
# i have this huge craving for mcdonalds ice cream----------------- {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.3869}
# @atlstro2 Tekashi is the goat. In all of my 45 years of life, I have never discovered an artist as great as Tekashi. Before discovering Tekashi gracious discography, I was broke. I worked at McDonalds. I’ve changed. Tekashi gave me a reason to exist. I love Tekashi. {'neg': 0.049, 'neu': 0.745, 'pos': 0.206, 'compound': 0.8779}
# @TitusNation I think @RepDLesko has the number of migrants confused with the number of @McDonalds hamburgers the former guy has eaten in the last 6 months. {'neg': 0.082, 'neu': 0.824, 'pos': 0.093, 'compound': -0.1779}
# Chick-fil-a Waffle Fries &gt;&gt;&gt;&gt;&gt;&gt;&gt; McDonalds Waffle Fries {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @VicKhiz item availability depends on the individual restaurant, Victor. for more info or to locate a store with the item availability near you, visit: https://t.co/n4jdHs8UmL {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @wolf_boss_ Ahh I see. Also a line from “The Founder” about the start of McDonalds {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Mcdonalds dipping sauce tier list. This is objectively correct, don't @ me. https://t.co/on876vjteG {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Since @DojaCat was able to bring the Mexican Pizza back to @tacobell, can someone make @McDonalds bring the breakfast bagels back?
#
# ALL. OF. THEM. PLEASE. {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.4648}
# @jaxinn On his way to McDonalds.--------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# U either quote tweet heron greenesmith on twitter or live long enough to see yourself become the cool nonbinary aunt who buys mcdonalds {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.34}
# @MidwestDad_ @SteakEggNcheeze @McDonalds Mettawa, IL off I-94 has em. 13783 West Oasis Service Road. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# (2)
# so don’t let the establishment tell you, you need to eat 20 times a day including sugars and carbs and mcdonalds. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# @kookoodoeeyes mcdonalds?---------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
data = pd.DataFrame(scores)
final_dataset= pd.concat([df,data], axis=1)

final_dataset.sort_values("likes" or "compound",ascending=False)
# Out:
#                                                tweets  likes  retweets  \
# 84  McDonalds Big Mac prices compared to Japanese ...     21         2
# 13  drunk n high rn waiting in the car for her to ...     16         0
# 72  Gonna get super stoned and finished all the sa...     11         0
# 77  Paddington is the Burger King to Winnie the Po...     10         1
# 88  @atlstro2 Tekashi is the goat. In all of my 45...      6         0
# ..                                                ...    ...       ...
# 25  @barstoolsports @martymush McDonalds large Cok...      0         0
# 69  unsan food // i hope shidou eats mcdonalds on ...      0         0
# 41  @barstoolsports @martymush A&amp;W root beer f...      0         0
# 71                     @jaxinn More likely McDonalds.      0         0
# 0   Former McDonald's CEO sets up group to fight b...      0         0
#
#                         time    neg    neu    pos  compound
# 84 2022-04-20 23:42:09+00:00  0.000  1.000  0.000    0.0000
# 13 2022-04-20 23:57:01+00:00  0.156  0.844  0.000   -0.3400
# 72 2022-04-20 23:45:01+00:00  0.000  0.851  0.149    0.3506
# 77 2022-04-20 23:43:30+00:00  0.058  0.942  0.000   -0.2960
# 88 2022-04-20 23:41:42+00:00  0.049  0.745  0.206    0.8779
# ..                       ...    ...    ...    ...       ...
# 25 2022-04-20 23:54:15+00:00  0.000  0.930  0.070    0.3274
# 69 2022-04-20 23:46:03+00:00  0.113  0.719  0.169    0.2023
# 41 2022-04-20 23:50:57+00:00  0.000  1.000  0.000    0.0000
# 71 2022-04-20 23:45:11+00:00  0.000  1.000  0.000    0.0000
# 0  2022-04-20 23:59:44+00:00  0.140  0.860  0.000   -0.3818
#
# [100 rows x 8 columns]

# %%
#final_dataset.to_sql(con=my_conn,name='test',if_exists='replace',index=False)

# %%
Text = final_dataset.iloc[0,0] 
for x in range(1,100):
    Text = Text + " " +  final_dataset.iloc[x,0]

# %%
# Cleaning text and lower casing all words
for char in '-.,\n':
    Text=Text.replace(char,' ')
Text = Text.lower()
# split returns a list of words delimited by sequences of whitespace (including tabs, newlines, etc, like re's \s) 
word_list = Text.split()

# %%
print(word_list)
# Out:
# ['former', "mcdonald's", 'ceo', 'sets', 'up', 'group', 'to', 'fight', 'back', 'against', 'woke', 'corporations', '|', 'daily', 'mail', 'online', 'https://t', 'co/m4ikil2hzy', '@yungmiami305', 'mcdonalds', 'burgers', 'are', 'made', 'with', 'human', 'remains', '@emilyscinto', '@mcdonalds', 'my', 'life', 'got', 'considerably', 'worse', 'when', 'i', "couldn't", 'get', 'an', 'egg', 'mcmuffin', 'for', 'dinner', '@jcincleveland', '@mcdonalds', 'and……', 'haha', 'bring', 'it', 'on', '@flippmint', 'sasha', 'waybright', 'as', 'the', 'mcdonalds', 'logo', ':d', 'i', 'woulda', 'had', 'mcdonalds', 'no', 'doubt', 'https://t', 'co/6dqacyqx8r', '@linnfucius', 'or', 'mcdonalds', 'pays', '$15/hr', 'so', 'in', '6hrs', 'someone', 'can', 'make', '$90', 'and', 'probably', 'have', 'more', 'fun', '@nm_uap', 'for', 'sure', 'its', 'not', 'cut', 'and', 'dried', 'what', 'does', 'putin', 'hope', 'to', 'rule', 'besides', 'ashes', '?', 'if', 'you', 'think', 'of', 'how', 'the', 'younger', 'generation', 'in', 'russia', 'must', 'feel', 'no', 'internet', 'no', 'netflix', 'no', 'spitify', 'no', 'mcdonalds', 'you', 'can', 'be', 'sure', 'there', 'is', 'a', 'deep', 'rooted', 'hatred', 'brewing', 'within', 'russia', 'itself', '#implosion', '@mcdonalds', 'you', 'can', 'do', 'better', 'than', 'this', 'my', 'son', 'just', 'screamed', '“give', 'me', 'my', 'drink”', 'through', 'the', 'window', 'at', 'the', 'drive', 'thru', 'cvs', 'pharmacy', 'tech', 'bro', 'this', 'is', 'not', 'mcdonalds', '@mcdonalds', 'what', "y'all", 'waiting', 'on???', 'https://t', 'co/aqi9syhxk1', '@intonerhen', 'now', 'i', 'want', 'a', 'chibi', 'show', 'about', 'mcdonalds', 'kaine', 'mcdonalds', 'question', 'mark', 'drunk', 'n', 'high', 'rn', 'waiting', 'in', 'the', 'car', 'for', 'her', 'to', 'bring', 'me', 'mcdonalds', '@mcdonalds', 'make', 'vegetarian', 'nuggets', 'or', 'begin', 'the', 'road', 'to', 'eventual', 'bankruptcy', 'like', 'it’s', 'ur', 'choice', 'waffle', 'fries', 'from', 'mcdonalds', 'r', 'mid', 'just', 'buy', 'normal', 'fries', 'former', '#mcdonalds', "'s", 'ceo', 'who', 'invented', 'the', 'mcnugget', 'sets', 'up', 'new', 'group', 'to', 'fight', 'back', 'against', 'woke', 'corporations', 'and', 'buys', 'enough', '#bankofamerica', 'shares', 'to', 'formally', 'propose', 'that', 'firm', 'scraps', 'staff', 'crt', 'training', 'https://t', 'co/5ls8yfog8l', '@verabambilive', '@mcdonalds', 'you', 'have', 'no', 'idea', 'how', 'hard', 'it', 'is', 'for', 'me', 'right', 'now', 'to', 'not', 'unfollow', 'you', 'just', 'for', 'the', 'sake', 'of', 'the', 'joke', 'before', 'making', 'six', 'figures', 'from', 'my', '9', '5', 'i', 'worked:', 'fast', 'food', 'mcdonalds', '🍔', 'retail', 'best', 'buy', '+', 'old', 'navy', '🛍', 'admin', 'college', '+', 'state', 'dept', '🗄', 'security', 'mall', '+', 'gap', '👮🏾\u200d♀️', 'delivery', 'fedex', '+', 'catering', '🚚', 'military', 'marines', '🥷🏾', 'by', '30', 'making', '$23k', 'b4', 'taxes', 'i’m', 'familiar', 'w/#thestruggle', '@mcdonalds', 'your', 'customer', 'support', 'is', '🚮', 'mcdonalds', 'gets', 'to', 'much', 'hate', 'i', 'mean', 'can', 'the', 'steady', 'diet', 'of', 'mcdonalds', 'kfc', 'diet', 'coke', 'and', 'adderall', 'just…', 'do', 'it’s', 'job', 'already?', 'i’m', 'so', 'fucking', 'sick', 'of', 'his', 'wretched', 'face', '🙄', 'https://t', 'co/x7maykb47y', '@anahibazan12', 'mcdonalds', 'frappe', '@tacobell', 'and', '@mcdonalds', 'y’all', 'can', 'stop', 'pretending', 'your', 'lobby’s', 'are', 'closed', 'for', 'the', 'safety', 'of', 'the', 'community', 'now', 'there', 'is', 'no', 'such', 'thing', 'as', 'fast', 'food', 'anymore', 'placed', 'my', 'mcdonalds', 'order', 'on', 'their', 'in', 'store', 'screen', 'at', '7:27', '7:54', 'and', 'still', 'no', 'food', '@barstoolsports', '@martymush', 'mcdonalds', 'large', 'coke', 'del', 'taco', 'cheesecake', 'bites', '5', 'guy', 'double', 'bacon', 'burger', 'in', 'n', 'out', 'double', 'double', 'arby’s', 'curly', 'fries', 'am', 'i', 'proud', 'of', 'this', 'list?', 'no!', 'but', 'it’s', 'the', 'right', 'list', '@barsto ...

# %%
# initializing a dictionary
d = {};

# counting number of times each word comes up in list of words
for key in word_list: 
    d[key] = d.get(key, 0) + 1

sorted(d.items(), key = lambda x: x[1], reverse = True)
# Out:
# [('mcdonalds', 61),
#  ('the', 58),
#  ('to', 39),
#  ('i', 35),
#  ('a', 31),
#  ('is', 26),
#  ('@mcdonalds', 24),
#  ('of', 24),
#  ('in', 23),
#  ('https://t', 20),
#  ('and', 19),
#  ('you', 17),
#  ('for', 16),
#  ('it', 14),
#  ('this', 14),
#  ('fries', 13),
#  ('that', 13),
#  ('my', 12),
#  ('at', 12),
#  ('as', 11),
#  ('have', 10),
#  ('from', 10),
#  ('=', 10),
#  ('with', 9),
#  ('on', 9),
#  ('no', 9),
#  ('me', 9),
#  ('are', 8),
#  ('not', 8),
#  ('all', 8),
#  ('just', 7),
#  ('like', 7),
#  ('was', 7),
#  ('former', 6),
#  ('up', 6),
#  ('back', 6),
#  ('get', 6),
#  ('an', 6),
#  ('bring', 6),
#  ('so', 6),
#  ('can', 6),
#  ('what', 6),
#  ('be', 6),
#  ('food', 6),
#  ('burger', 6),
#  ('ceo', 5),
#  ('sets', 5),
#  ('group', 5),
#  ('fight', 5),
#  ('woke', 5),
#  ('corporations', 5),
#  ('or', 5),
#  ('more', 5),
#  ('about', 5),
#  ('your', 5),
#  ('kfc', 5),
#  ('double', 5),
#  ('we', 5),
#  ('lil', 5),
#  ('has', 5),
#  ('jpy', 5),
#  ('tekashi', 5),
#  ("mcdonald's", 4),
#  ('against', 4),
#  ('life', 4),
#  ('had', 4),
#  ('sure', 4),
#  ('it’s', 4),
#  ('before', 4),
#  ('+', 4),
#  ('diet', 4),
#  ('coke', 4),
#  ('their', 4),
#  ('@barstoolsports', 4),
#  ('@martymush', 4),
#  ('but', 4),
#  ('chicken', 4),
#  ('happy', 4),
#  ('great', 4),
#  ('never', 4),
#  ('yeat', 4),
#  ('years', 4),
#  ('pump', 4),
#  ('made', 3),
#  ('make', 3),
#  ('if', 3),
#  ('how', 3),
#  ('there', 3),
#  ('do', 3),
#  ('now', 3),
#  ('n', 3),
#  ('waffle', 3),
#  ('new', 3),
#  ('enough', 3),
#  ('fast', 3),
#  ('i’m', 3),
#  ('mean', 3),
#  ('his', 3),
#  ('order', 3),
#  ('large', 3),
#  ('out', 3),
#  ('arby’s', 3),
#  ('curly', 3),
#  ('@jaxinn', 3),
#  ('big', 3),
#  ('mac', 3),
#  ('don’t', 3),
#  ('mcdonald’s', 3),
#  ('crunch', 3),
#  ('give', 3),
#  ('will', 3),
#  ('those', 3),
#  ("don't", 3),
#  ('item', 3),
#  ('number', 3),
#  ('go', 3),
#  ('(i', 3),
#  ('@atlstro2', 3),
#  ('goat', 3),
#  ('45', 3),
#  ('discovered', 3),
#  ('artist', 3),
#  ('discovering', 3),
#  ('gracious', 3),
#  ('discography', 3),
#  ('broke', 3),
#  ('worked', 3),
#  ('i’ve', 3),
#  ('changed', 3),
#  ('gave', 3),
#  ('reason', 3),
#  ('exist', 3),
#  ('love', 3),
#  ('they', 3),
#  ('@emilyscinto', 2),
#  ('when', 2),
#  ('dinner', 2),
#  ('someone', 2),
#  ('fun', 2),
#  ('does', 2),
#  ('hope', 2),
#  ('think', 2),
#  ('russia', 2),
#  ('must', 2),
#  ('better', 2),
#  ('than', 2),
#  ('waiting', 2),
#  ('her', 2),
#  ('nuggets', 2),
#  ('road', 2),
#  ('buy', 2),
#  ('#mcdonalds', 2),
#  ('who', 2),
#  ('buys', 2),
#  ('staff', 2),
#  ('@verabambilive', 2),
#  ('hard', 2),
#  ('right', 2),
#  ('making', 2),
#  ('5', 2),
#  ('best', 2),
#  ('by', 2),
#  ('gets', 2),
#  ('much', 2),
#  ('@tacobell', 2),
#  ('thing', 2),
#  ('store', 2),
#  ('taco', 2),
#  ('guy', 2),
#  ('bacon', 2),
#  ('list', 2),
#  ('oreo', 2),
#  ('fry', 2),
#  ('these', 2),
#  ('days', 2),
#  ('2', 2),
#  ('hours', 2),
#  ('ago', 2),
#  ('😀', 2),
#  ('going', 2),
#  ('cheeseburger', 2),
#  ('meal', 2),
#  ('apple', 2),
#  ('mcdonalds?', 2),
#  ('need', 2),
#  ('6', 2),
#  ('tweet', 2),
#  ('times', 2),
#  ('sandwich', 2),
#  ('five', 2),
#  ('guys', 2),
#  ('some', 2),
#  ('shit', 2),
#  ('@wendys', 2),
#  ('after', 2),
#  ('filling', 2),
#  ('would', 2),
#  ('free', 2),
#  ('@tfswebb', 2),
#  ("i'm", 2),
#  ('sold', 2),
#  ('until', 2),
#  ('which', 2),
#  ('drink', 2),
#  ('!', 2),
#  ("you're", 2),
#  ('gonna', 2),
#  ('saying', 2),
#  ('might', 2),
#  ('sprite', 2),
#  ('12', 2),
#  ('chicfila', 2),
#  ('really', 2),
#  ('popeyes', 2),
#  ('@bladee90210', 2),
#  ('via', 2),
#  ('he', 2),
#  ('then', 2),
#  ('100%', 2),
#  ('also', 2),
#  ('last', 2),
#  ('price', 2),
#  ('japan', 2),
#  ('costs', 2),
#  ('availability', 2),
#  ('see', 2),
#  ('|', 1),
#  ('daily', 1),
#  ('mail', 1),
#  ('online', 1),
#  ('co/m4ikil2hzy', 1),
#  ('@yungmiami305', 1),
#  ('burgers', 1),
#  ('human', 1),
#  ('remains', 1),
#  ('got', 1),
#  ('considerably', 1),
#  ('worse', 1),
#  ("couldn't", 1),
#  ('egg', 1),
#  ('mcmuffin', 1),
#  ('@jcincleveland', 1),
#  ('and……', 1),
#  ('haha', 1),
#  ('@flippmint', 1),
#  ('sasha', 1),
#  ('waybright', 1),
#  ('logo', 1),
#  (':d', 1),
#  ('woulda', 1),
#  ('doubt', 1),
#  ('co/6dqacyqx8r', 1),
#  ('@linnfucius', 1),
#  ('pays', 1),
#  ('$15/hr', 1),
#  ('6hrs', 1),
#  ('$90', 1),
#  ('probably', 1),
#  ('@nm_uap', 1),
#  ('its', 1),
#  ('cut', 1),
#  ('dried', 1),
#  ('putin', 1),
#  ('rule', 1),
#  ('besides', 1),
#  ('ashes', 1),
#  ('?', 1),
#  ('younger', 1),
#  ('generation', 1),
#  ('feel', 1),
#  ('internet', 1),
#  ('netflix', 1),
#  ('spitify', 1),
#  ('deep', 1),
#  ('rooted', 1),
#  ('hatred', 1),
#  ('brewing', 1),
#  ('within', 1),
#  ('itself', 1),
#  ('#implosion', 1),
#  ('son', 1),
#  ('screamed', 1),
#  ('“give', 1),
#  ('drink”', 1),
#  ('through', 1),
#  ('window', 1),
#  ('drive', 1),
#  ('thru', 1),
#  ('cvs', 1),
#  ('pharmacy', 1),
#  ('tech', 1),
#  ('bro', 1),
#  ("y'all", 1),
#  ('on???', 1),
#  ('co/aqi9syhxk1', 1),
#  ('@intonerhen', 1),
#  ('want', 1),
#  ('chibi', 1),
#  ('show', 1),
#  ('kaine', 1),
#  ('question', 1),
#  ('mark', 1),
#  ('drunk', 1),
#  ('high', 1),
#  ('rn', 1),
#  ('car', 1),
#  ('vegetarian', 1),
#  ('begin', 1),
#  ('eventual', 1),
#  ('bankruptcy', 1),
#  ('ur', 1),
#  ('choice', 1),
#  ('r', 1),
#  ('mid', 1),
#  ('normal', 1),
#  ("'s", 1),
#  ('invented', 1),
#  ('mcnugget', 1),
#  ('#bankofamerica', 1),
#  ('shares', 1),
#  ('formally', 1),
#  ('propose', 1),
#  ('firm', 1),
#  ('scraps', 1),
#  ('crt', 1),
#  ('training', 1),
#  ('co/5ls8yfog8l', 1),
#  ('idea', 1),
#  ('unfollow', 1),
#  ('sake', 1),
#  ('joke', 1),
#  ('six', 1),
#  ('figures', 1),
#  ('9', 1),
#  ('worked:', 1),
#  ('🍔', 1),
#  ('retail', 1),
#  ('old', 1),
#  ('navy', 1),
#  ('🛍', 1),
#  ('admin', 1),
#  ('college', 1),
#  ('state', 1),
#  ('dept', 1),
#  ('🗄', 1),
#  ('security', 1),
#  ('mall', 1),
#  ('gap', 1),
#  ('👮🏾\u200d♀️', 1),
#  ('delivery', 1),
#  ('fedex', 1),
#  ('catering', 1),
#  ('🚚', 1),
#  ('military', 1),
#  ('marines', 1),
#  ('🥷🏾', 1),
#  ('30', 1),
#  ('$23k', 1),
#  ('b4', 1),
#  ('taxes', 1),
#  ('familiar', 1),
#  ('w/#thestruggle', 1),
#  ('customer', 1),
#  ('support', 1),
#  ('🚮', 1),
#  ('hate', 1),
#  ('steady', 1),
#  ('adderall', 1),
#  ('just…', 1),
#  ('job', 1),
#  ('already?', 1),
#  ('fucking', 1),
#  ('sick', 1),
#  ('wretched', 1),
#  ('face', 1),
#  ('🙄', 1),
#  ('co/x7maykb47y', 1),
#  ('@anahibazan12', 1),
#  ('frappe', 1),
#  ('y’all', 1),
#  ('stop', 1),
#  ('pretending', 1),
#  ('lobby’s', 1),
#  ('closed', 1),
#  ('safety', 1),
#  ('community', 1),
#  ('such', 1),
#  ('anymore', 1),
#  ('placed', 1),
#  ('screen', 1),
#  ('7:27', 1),
#  ('7:54', 1),
#  ('still', 1),
#  ('del', 1),
#  ('cheesecake', 1),
#  ('bites', 1),
#  ('am', 1),
#  ('proud', 1),
#  ('list?', 1),
#  ('no!', 1),
#  ('popcorn', 1),
#  ('original', 1),
#  ('spicy', 1),
#  ('wendy’s', 1),
#  ('potbelly', 1),
#  ('shake', 1),
#  ('come', 1),
#  ('co/pitzq0qtcf', 1),
#  ('*banned', 1),
#  ('mcdonalds*', 1),
#  ('even', 1),
#  ('kidding', 1),
#  ('soda', 1),
#  ('friend', 1),
#  ('bought', 1),
#  ('caved', 1),
#  ('another', 1),
#  ('@craig_soderdahl', 1),
#  ('same?', 1),
#  ('1st', 1),
#  ('marketing', 1),
#  ('co', 1),
#  ('2nd', 1),
#  ('re', 1),
#  ('company', 1),
#  ('3rd', 1),
#  ('joint?', 1),
#  ('@foxnews', 1),
#  ('@gop', 1),
#  ('@gopchairwoman', 1),
#  ('pictured', 1),
#  ('here', 1),
#  ('having', 1),
#  ('received', 1),
#  ('news', 1),
#  ('donald', 1),
#  ('trump', 1),
#  ('feed', 1),
#  ('part', 1),
#  ('reality', 1),
#  ('prank', 1),
#  ('series', 1),
#  ('premiering', 1),
#  ('sunday', 1),
#  ('@mtv', 1),
#  ('somehow', 1),
#  ('believe', 1),
#  ('meant', 1),
#  ('slices', 1),
#  ('co/bjkqyzczpe', 1),
#  ('co/rtmj2mqimc', 1),
#  ('co/p2dxgljzao', 1),
#  ('@mailonline', 1),
#  ('co/tzrj1oysqa', 1),
#  ('blue', 1),
#  ('powerade', 1),
#  ('m&amp;m', 1),
#  ('mcflurry', 1),
#  ('wrap', 1),
#  ('supreme', 1),
#  ('tbell', 1),
#  ('3x3', 1),
#  ('animal', 1),
#  ('style', 1),
#  ('checkers', 1),
#  ('co/8zakqmxxgc', 1),
#  ('@iamrichwilson', 1),
#  ('clear', 1),
#  ("greg's", 1),
#  ('gnerally/', 1),
#  ('ginsters', 1),
#  ('(usually', 1),
#  ('main', 1),
#  ('stand', 1),
#  ('up)?', 1),
#  ('dirty', 1),
#  ('it?', 1),
#  ('incentive', 1),
#  ('commission', 1),
#  ('vote', 1),
#  ('different', 1),
#  ('map', 1),
#  ('meets', 1),
#  ('constitutional', 1),
#  ('muster?', 1),
#  ('none', 1),
#  ('telling', 1),
#  ('child', 1),
#  ('pick', 1),
#  ('healthy', 1),
#  ('option', 1),
#  ('5:59…then', 1),
#  ('forced', 1),
#  ('#fairmaps', 1),
#  ('co/nmvt4kmlgu', 1),
#  ('done', 1),
#  ('seen', 1),
#  ('rif', 1),
#  ('application', 1),
#  ('16', 1),
#  ('today', 1),
#  ('a&amp;w', 1),
#  ('root', 1),
#  ('beer', 1),
#  ('float', 1),
#  ('pie', 1),
#  ('@codinghorror', 1),
#  ('franchises', 1),
#  ('@_penname', 1),
#  ('oooooohhhhhh!', 1),
#  ('walked', 1),
#  ('house', 1),
#  ('idea!', 1),
#  ('snack', 1),
#  ('tomorrow', 1),
#  (':)', 1),
#  ('@tintamarre6', 1),
#  ('$15', 1),
#  ('hour', 1),
#  ('minimum', 1),
#  ('wage', 1),
#  ('passed', 1),
#  ('nationally', 1),
#  ('@delusionsmass', 1),
#  ('@bl20422822', 1),
#  ('@alexvickeryhowe', 1),
#  ('@6lennybravo', 1),
#  ('@jaisans', 1),
#  ('@minnesotaexpat', 1),
#  ('@ram0667', 1),
#  ('@alfred_statesx', 1),
#  ('@asinister', 1),
#  ('@glinch72', 1),
#  ('@medbennett', 1),
#  ('@corpulentwidow', 1),
#  ('@debrammason1', 1),
#  ('@jonrfleming', 1),
#  ('@thedvsmarcus', 1),
#  ('@walrusesarecool', 1),
#  ('@johnoz1900', 1),
#  ('@girl_pilled', 1),
#  ('@alefty123', 1),
#  ('@cbeckj', 1),
#  ('@barbarajdurkin', 1),
#  ('@insane_voice', 1),
#  ('@navybrat59', 1),
#  ('@itstheatmospher', 1),
#  ('@anvndarnamn5', 1),
#  ('@deniersarederp', 1),
#  ('@fishyfish67', 1),
#  ('@shastagecko', 1),
#  ('@educatingtrump2', 1),
#  ('@neilcharles1450', 1),
#  ('@gswarthout', 1),
#  ('@jeffbernard1', 1),
#  ('@based_inreality', 1),
#  ('@robertvonb1', 1),
#  ('@rustyaway', 1),
#  ('@chrisbbacon3', 1),
#  ('@bellronibell', 1),
#  ('@jonnyporkchop', 1),
#  ('@damienhamilto17', 1),
#  ('@biffmack', 1),
#  ('@racing_mackay', 1),
#  ('@jpgcrowley', 1),
#  ('@garywhall', 1),
#  ('@lorrilala', 1),
#  ('@andyboulo', 1),
#  ('@ponycar06', 1),
#  ('@canalzone68', 1),
#  ('@kevinsecular2', 1),
#  ('@seanflan45', 1),
#  ('@narvuntien', 1),
#  ('imagine', 1),
#  ('smell', 1),
#  ('playing', 1),
#  ('golf', 1),
#  ('hot', 1),
#  ('humid', 1),
#  ('florida', 1),
#  ('sun', 1),
#  ('drinking', 1),
#  ('cokes', 1),
#  ('pounding', 1),
#  ('diapers', 1),
#  ('yikes', 1),
#  ('concludes', 1),
#  ("today's", 1),
#  ('class', 1),
#  ('cash', 1),
#  ('(which', 1),
#  ('validate', 1),
#  ('earth', 1),
#  ('during', 1),
#  ('dust', 1),
#  ('bars', 1),
#  ('mcdonalds!', 1),
#  ('@mmichaelllucy', 1),
#  ('derives', 1),
#  ('junior', 1),
#  ('menu', 1),
#  ('australia', 1),
#  ('early', 1),
#  ('2000s', 1),
#  ('(?)', 1),
#  ('bit', 1),
#  ('find', 1),
#  ('cursory', 1),
#  ('google', 1),
#  ('became', 1),
#  ('"hamburger"', 1),
#  ('pretty', 1),
#  ('always', 1),
#  ('us:', 1),
#  ('co/1lhei5gorw', 1),
#  ('@kimshijin8', 1),
#  ('@youknowstobit', 1),
#  ('tae', 1),
#  ('scene', 1),
#  ('cute!!!', 1),
#  ('full', 1),
#  ('middle', 1),
#  ('schoolers', 1),
#  ('😂', 1),
#  ('@andreas43937443', 1),
#  ('@mysterysolvent', 1),
#  ('two', 1),
#  ('ass', 1),
#  ('nozzles', 1),
#  ('fake', 1),
#  ('tanned', 1),
#  ('nutsacks', 1),
#  ('(suspiciously', 1),
#  ('orange', 1),
#  ('colored', 1),
#  ('dripping', 1),
#  ('flop', 1),
#  ('sweat)', 1),
#  ('"orange', 1),
#  ('"', 1),
#  ('cinnamon', 1),
#  ('danish', 1),
#  ('used', 1),
#  ('sell', 1),
#  ('@deannam_409', 1),
#  ('mcds', 1),
#  ("wendy's", 1),
#  ('frosty', 1),
#  ('@team_dji', 1),
#  ('wow!!!', 1),
#  ('repost', 1),
#  ('mine!!', 1),
#  ('@ovrhtd', 1),
#  ('aal', 1),
#  ('water', 1),
#  ('mcdonalds!/!', 1),
#  ('‘man', 1),
#  ('@cltyofmon', 1),
#  ('were', 1),
#  ('associating', 1),
#  ('noises', 1),
#  ('bg', 1),
#  ('collab', 1),
#  ('😭', 1),
#  ('@prankstercleric', 1),
#  ('keep', 1),
#  ('end', 1),
#  ('believing', 1),
#  ('/just/', 1),
#  ('capn', 1),
#  ('delights', 1),
#  ('bell', 1),
#  ('pc', 1),
#  ('😋', 1),
#  ('@goatisse', 1),
#  ('👀👀', 1),
#  ('mcdonalds??', 1),
#  ('assume', 1),
#  ('comes', 1),
#  ('was/is', 1),
#  ('smallest', 1),
#  ('least', 1),
#  ('ingredients/fillings', 1),
#  ('oh', 1),
#  ('goodness!', 1),
#  ('responded!', 1),
#  ('you’ve', 1),
#  ('it!', 1),
#  ('@lokelanirocks', 1),
#  ('mcdonalds!!!🤦\u200d♂️😂😂😂😂', 1),
#  ('bad', 1),
#  ('coffee', 1),
#  ('conclusion', 1),
#  ('ever', 1),
#  ('again🧍\u200d♂️🧍\u200d♂️', 1),
#  ('okay', 1),
#  ('freddies', 1),
#  ('panera', 1),
#  ('whataburger', 1),
#  ('chickfila', 1),
#  ('everyday', 1),
#  ('though)', 1),
#  ('yesterday)', 1),
#  ('forgot', 1),
#  ('omg)', 1),
#  ('one????', 1),
#  ('@risenphoenix01', 1),
#  ("yeat's", 1),
#  ('@lenicrook', 1),
#  ('answered', 1),
#  ('me…still', 1),
#  ('terrible', 1),
#  ('though', 1),
#  ('gallery', 1),
#  ('place', 1),
#  ('it!!!!!', 1),
#  ('sodas', 1),
#  ('flat', 1),
#  ('juice', 1),
#  ('watery', 1),
#  ('af', 1),
#  ('🤮🤮🤮', 1),
#  ('check', 1),
#  ('toys', 1),
#  ('lot', 1),
#  ('hercules/aladdin/chronicles', 1),
#  ('narnia', 1),
#  ('co/hztczfbrna', 1),
#  ('#ebay', 1),
#  ('@ebay', 1),
#  ('#toys', 1),
#  ('#nostalgia', 1),
#  ('#happymeal', 1),
#  ('pump’s', 1),
#  ('unsan', 1),
#  ('//', 1),
#  ('shidou', 1),
#  ('eats', 1),
#  ('trip', 1),
#  ('kentucky', 1),
#  ('home', 1),
#  ('well', 1),
#  ("it's", 1),
#  ('been', 1),
#  ('vera', 1),
#  ('shame', 1),
#  ('our', 1),
#  ('friendship', 1),
#  ('ended', 1),
#  ('over', 1),
#  ('donuts', 1),
#  ('co/uufzhk8mg9', 1),
#  ('likely', 1),
#  ('super', 1),
#  ('stoned', 1),
#  ('finished', 1),
#  ('saw', 1),
#  ('movies', 1),
#  ('first…', 1),
#  ('🧑\u200d🏭', 1),
#  ('absolutely', 1),
#  ('nobody', 1),
#  ('all:', 1),
#  ('house:', 1),
#  ('co/s3k1tcvzup', 1),
#  ('@getclipped1738', 1),
#  ('@muvarell', 1),
#  ('@maceojernigan', 1),
#  ('there’s', 1),
#  ('chance', 1),
#  ('work', 1),
#  ('level', 1),
#  ('intelligence', 1),
#  ('🥴', 1),
#  ('lockdown', 1),
#  ('messed', 1),
#  ('paddington', 1),
#  ('king', 1),
#  ('winnie', 1),
#  ('pooh’s', 1),
#  ('far', 1),
#  ('“a', 1),
#  ('boy', 1),
#  ('bear”', 1),
#  ('subgenre', 1),
#  ('goes', 1),
#  ('revenant', 1),
#  ('falls', 1),
#  ('into', 1),
#  ('category', 1),
#  ('denny’s', 1),
#  ('elaborate', 1),
#  ('freestlye', 1),
#  ('machine', 1),
#  ('vanilla', 1),
#  ('wendys', 1),
#  ('chocolate', 1),
#  ('frostie', 1),
#  ('cheesey', 1),
#  ('gordita', 1),
#  ('co/hc2wcohrer', 1),
#  ('@_mirandawrites', 1),
#  ('help', 1),
#  ('miranda', 1),
#  ("let's", 1),
#  ('talk', 1),
#  ('detail', 1),
#  ('location', 1),
#  ('link:', 1),
#  ('co/whvwt8dw7y', 1),
#  ('@potus', 1),
#  ('@bill_maxwell_', 1),
#  ('noticed', 1),
#  ('local', 1),
#  ('staying', 1),
#  ('open', 1),
#  ('till', 1),
#  ('2am', 1),
#  ('(not', 1),
#  ('i’ll', 1),
#  ('hour)', 1),
#  ('employees', 1),
#  ('pay', 1),
#  ('@laurenboebert', 1),
#  ('few', 1),
#  ('examples', 1),
#  ('stuff', 1),
#  ('conversatives', 1),
#  ('tried', 1),
#  ('protesting', 1),
#  ('against:', 1),
#  ('nike', 1),
#  ('coca', 1),
#  ('cola', 1),
#  ('pepsi', 1),
#  ('gillette', 1),
#  ('kelloggs', 1),
#  ('amazon', 1),
#  ('target', 1),
#  ('nascar', 1),
#  ('kuerig', 1),
#  ('wal', 1),
#  ('mart', 1),
#  ('ups', 1),
#  ('mlb', 1),
#  ('delta', 1),
#  ('airlines', 1),
#  ('cisco', 1),
#  ('quaker', 1),
#  ('citibank', 1),
#  ('broke?', 1),
#  ('thank', 1),
#  ('feeding', 1),
#  ('3', 1),
#  ('using', 1),
#  ('app', 1),
#  ('mcchicken', 1),
#  ('sweet', 1),
#  ('tea', 1),
#  ('$2', 1),
#  ('86', 1),
#  ('kyrie', 1),
#  ('he’ll', 1),
#  ('40', 1),
#  ('prices', 1),
#  ('compared', 1),
#  ('japanese', 1),
#  ('(local', 1),
#  ('converted', 1),
#  ('jpy)', 1),
#  ('390', 1),
#  ('singapore', 1),
#  ('539', 1),
#  ('139%', 1),
#  ('uk', 1),
#  ('585', 1),
#  ('150%', 1),
#  ('zealand', 1),
#  ('694', 1),
#  ('178%', 1),
#  ('usa', 1),
#  ('773', 1),
#  ('198%', 1),
#  ('us', 1),
#  ('@brikiorr', 1),
#  ('receiving', 1),
#  ('cold', 1),
#  ('should', 1),
#  ('illegal', 1),
#  ('cos', 1),
#  ('clock', 1),
#  ('real', 1),
#  ("can't", 1),
#  ('stay', 1),
#  ('silent', 1),
#  ('any', 1),
#  ('longer', 1),
#  ('gone', 1),
#  ('hell', 1),
#  ('handbasket', 1),
#  ('only', 1),
#  ('continues', 1),
#  ('edible', 1),
#  ('rest', 1),
#  ('mess', 1),
#  ('fixed', 1),
#  ('huge', 1),
#  ('craving', 1),
#  ('ice', 1),
#  ('cream', 1),
#  ('@titusnation', 1),
#  ('@repdlesko', 1),
#  ('migrants', 1),
#  ('confused', 1),
#  ('hamburgers', 1),
#  ('eaten', 1),
#  ('months', 1),
#  ('chick', 1),
#  ('fil', 1),
#  ('&gt;&gt;&gt;&gt;&gt;&gt;&gt;', 1),
#  ('@vickhiz', 1),
#  ('depends', 1),
#  ('individual', 1),
#  ('restaurant', 1),
#  ('victor', 1),
#  ('info', 1),
#  ('locate', 1),
#  ('near', 1),
#  ('visit:', 1),
#  ('co/n4jdhs8uml', 1),
#  ('@wolf_boss_', 1),
#  ('ahh', 1),
#  ('line', 1),
#  ('“the', 1),
#  ('founder”', 1),
#  ('start', 1),
#  ('dipping', 1),
#  ('sauce', 1),
#  ('tier', 1),
#  ('objectively', 1),
#  ('correct', 1),
#  ('@', 1),
#  ('co/on876vjteg', 1),
#  ('since', 1),
#  ('@dojacat', 1),
#  ('able', 1),
#  ('mexican', 1),
#  ('pizza', 1),
#  ('breakfast', 1),
#  ('bagels', 1),
#  ('back?', 1),
#  ('them', 1),
#  ('please', 1),
#  ('way', 1),
#  ('u', 1),
#  ('either', 1),
#  ('quote', 1),
#  ('heron', 1),
#  ('greenesmith', 1),
#  ('twitter', 1),
#  ('live', 1),
#  ('long', 1),
#  ('yourself', 1),
#  ('become', 1),
#  ('cool', 1),
#  ('nonbinary', 1),
#  ('aunt', 1),
#  ('@midwestdad_', 1),
#  ('@steakeggncheeze', 1),
#  ('mettawa', 1),
#  ('il', 1),
#  ('off', 1),
#  ('94', 1),
#  ('em', 1),
#  ('13783', 1),
#  ('west', 1),
#  ('oasis', 1),
#  ('service', 1),
#  ('(2)', 1),
#  ('let', 1),
#  ('establishment', 1),
#  ('tell', 1),
#  ('eat', 1),
#  ('20', 1),
#  ('day', 1),
#  ('including', 1),
#  ('sugars', 1),
#  ('carbs', 1),
#  ('@kookoodoeeyes', 1)]
